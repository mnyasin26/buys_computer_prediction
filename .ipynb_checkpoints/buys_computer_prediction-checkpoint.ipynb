# %% [markdown]
# # Importing Libraries

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install plotly
# !pip install sklearn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Importing Data

# %%
df = pd.read_csv("train_buys_computer.csv", index_col=0)
df_test = pd.read_csv("test_buys_computer.csv", index_col=0)

# %%
df.head()
# Out:
#              income student credit_rating buys_computer
# age
# youth          high      no          fair            no
# youth          high      no     excellent            no
# middle_aged    high      no          fair           yes
# senior       medium      no          fair           yes
# senior          low     yes          fair           yes

# %%
for i in df.columns:
    print("-------------------")
    print(i," : ",df[i].unique())
# Out:
# -------------------
# income  :  ['high' 'medium' 'low']
# -------------------
# student  :  ['no' 'yes']
# -------------------
# credit_rating  :  ['fair' 'excellent']
# -------------------
# buys_computer  :  ['no' 'yes']

# %%
#info of train dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, youth to senior
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   income         14 non-null     object
#  1   student        14 non-null     object
#  2   credit_rating  14 non-null     object
#  3   buys_computer  14 non-null     object
# dtypes: object(4)
# memory usage: 560.0+ bytes

# %% [markdown]
# # Cleaning the Dataset

# %%
#null values in dataset
df.isnull().sum()
# Out:
# income           0
# student          0
# credit_rating    0
# buys_computer    0
# dtype: int64

# %%
#removing null values
df = df.dropna(how='any',axis=0)

# %%
df.isnull().sum()
# Out:
# income           0
# student          0
# credit_rating    0
# buys_computer    0
# dtype: int64

# %%
#removing unnecessary variable
df.drop(['fnlwgt'], inplace=True, axis='columns')

# %%
df.head(50)
# Out:
#              income student credit_rating buys_computer
# age
# youth          high      no          fair            no
# youth          high      no     excellent            no
# middle_aged    high      no          fair           yes
# senior       medium      no          fair           yes
# senior          low     yes          fair           yes
# senior          low     yes     excellent            no
# middle_aged     low     yes     excellent           yes
# youth        medium      no          fair            no
# youth           low     yes          fair           yes
# senior       medium     yes          fair           yes
# youth        medium     yes     excellent           yes
# middle_aged  medium      no     excellent           yes
# middle_aged    high     yes          fair           yes
# senior       medium      no     excellent            no

# %% [markdown]
# # Exploring the Dataset

# %% [markdown]
# ### Numerical variables

# %%
#exploring the age variable
df['student'].describe()
# Out:
# count     14
# unique     2
# top       no
# freq       7
# Name: student, dtype: object

# %%
#boxplot for age variable
fig = px.box(df, y='age', color='buys_computer', title='Income level based on the age of an individual', labels={'y':'Age', 'x':'Buys Computer'})
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 #boxplot for age variable
# ----> 2 fig = px.box(df, y='age', color='incomelevel', title='Income level based on the age of an individual', labels={'y':'Age', 'x':'Income level'})
#       3 fig.show()
#
# File D:\Users\vamou\anaconda3\lib\site-packages\plotly\express\_chart_types.py:652, in box(data_frame, x, y, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, orientation, boxmode, log_x, log_y, range_x, range_y, points, notched, title, template, width, height)
#     611 def box(
#     612     data_frame=None,
#     613     x=None,
#    (...)
#     641     height=None,
#     642 ):
#     643     """
#     644     In a box plot, rows of `data_frame` are grouped together into a
#     645     box-and-whisker mark to visualize their distribution.
#    (...)
#     650     range (IQR: Q3-Q1), see "points" for other options.
#     651     """
# --> 652     return make_figure(
#     653         args=locals(),
#     654         constructor=go.Box,
#     655         trace_patch=dict(boxpoints=points, notched=notched, x0=" ", y0=" "),
#     656         layout_patch=dict(boxmode=boxmode),
#     657     )
#
# File D:\Users\vamou\anaconda3\lib\site-packages\plotly\express\_core.py:1945, in make_figure(args, constructor, trace_patch, layout_patch)
#    1942 layout_patch = layout_patch or {}
#    1943 apply_default_cascade(args)
# -> 1945 args = build_dataframe(args, constructor)
#    1946 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1947     args = process_dataframe_hierarchy(args)
#
# File D:\Users\vamou\anaconda3\lib\site-packages\plotly\express\_core.py:1405, in build_dataframe(args, constructor)
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File D:\Users\vamou\anaconda3\lib\site-packages\plotly\express\_core.py:1207, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1205         if argument == "index":
#    1206             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207         raise ValueError(err_msg)
#    1208 elif length and len(df_input[argument]) != length:
#    1209     raise ValueError(
#    1210         "All arguments should have the same length. "
#    1211         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1218         )
#    1219     )
#
# ValueError: Value of 'y' is not the name of a column in 'data_frame'. Expected one of ['income', 'student', 'credit_rating', 'buys_computer'] but received: age

# %%
#exploring educationnum variable
df['educationnum'].describe()
# Out:
# count    30162.000000
# mean        10.121312
# std          2.549995
# min          1.000000
# 25%          9.000000
# 50%         10.000000
# 75%         13.000000
# max         16.000000
# Name: educationnum, dtype: float64

# %%
#boxplot for educationnum variable
fig = px.box(df, y='educationnum', color='incomelevel', title='Years of education distribution for different income levels', labels={'y':'Age', 'x':'Income level'})
fig.show()
# Out:
# <div>                            <div id="1166175a-c907-4e14-8a43-e7c786bef786" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1166175a-c907-4e14-8a43-e7c786bef786")) {                    Plotly.newPlot(                        "1166175a-c907-4e14-8a43-e7c786bef786",                        [{"alignmentgroup":"True","hovertemplate":"incomelevel=<=50K<br>educationnum=%{y}<extra></extra>","legendgroup":"<=50K","marker":{"color":"#636efa"},"name":"<=50K","notched":false,"offsetgroup":"<=50K","orientation":"v","showlegend":true,"type":"box","x0":" ","xaxis":"x","y":[13,13,9,7,13,14,5,13,12,4,9,9,7,9,5,7,9,9,9,9,12,10,13,10,10,7,10,9,12,5,13,13,9,9,9,14,11,11,10,9,3,11,9,9,13,9,10,9,10,10,13,10,10,9,12,7,4,9,13,9,9,9,14,5,11,10,10,10,12,9,14,10,9,7,9,9,13,10,9,5,10,10,9,10,13,13,10,10,10,12,9,9,13,12,9,11,10,9,10,10,10,9,10,9,7,10,9,13,9,9,13,10,9,13,9,14,9,10,12,14,7,11,9,9,13,9,9,9,9,13,10,10,9,13,14,10,10,13,10,13,3,10,9,14,10,9,7,9,7,9,10,9,12,13,13,6,10,9,9,1,9,9,11,9,7,9,10,10,9,10,9,9,12,10,9,13,6,10,10,9,9,11,4,13,9,7,10,7,13,5,14,14,9,9,10,10,13,12,13,9,10,13,4,13,9,13,10,13,9,13,9,9,10,10,9,12,12,13,10,10,10,3,10,9,9,10,9,7,14,9,9,9,10,13,11,6,9,3,9,14,9,9,12,9,10,13,12,13,9,7,7,9,5,6,13,9,9,10,12,9,10,7,9,9,10,9,10,14,9,9,3,10,10,10,9,9,10,9,13,12,9,10,10,10,10,11,4,9,9,10,10,9,10,10,2,7,7,9,10,7,9,6,9,14,9,14,13,10,9,10,10,10,13,9,9,5,10,9,9,9,9,9,10,9,12,9,13,2,13,9,9,10,9,9,11,13,5,10,6,9,12,10,13,9,10,9,13,9,9,12,9,13,9,10,3,10,9,9,10,10,13,13,10,10,9,9,11,11,9,10,10,10,10,9,14,7,9,9,8,2,11,13,10,16,10,9,10,9,6,10,9,10,10,9,7,9,7,9,9,7,13,9,9,14,4,9,14,9,9,7,16,12,13,10,9,9,13,10,10,7,13,13,9,10,13,13,10,4,5,12,9,9,9,6,14,9,9,13,13,9,9,9,13,13,7,5,11,5,9,9,10,6,9,9,13,3,9,9,10,10,9,9,10,9,10,9,10,9,4,14,10,14,10,10,5,10,7,9,8,10,9,9,9,10,7,9,13,14,9,10,10,10,10,
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99999.000000
# Name: capitalgain, dtype: float64

# %%
df['capitalloss'].describe()
# Out:
# count    30162.000000
# mean        88.372489
# std        404.298370
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       4356.000000
# Name: capitalloss, dtype: float64

# %%
#exploring hours/week variable
df['hoursperweek'].describe()
# Out:
# count    30162.000000
# mean        40.931238
# std         11.979984
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hoursperweek, dtype: float64

# %%
#boxplot for hoursperweek variable
fig = px.box(df, y='hoursperweek', color='incomelevel', title='Hours per week distribution for different income levels', labels={'y':'Age', 'x':'Income level'})
fig.show()
# Out:
# <div>                            <div id="6e2e86d3-2d65-4d5d-acfa-922132f3143e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e2e86d3-2d65-4d5d-acfa-922132f3143e")) {                    Plotly.newPlot(                        "6e2e86d3-2d65-4d5d-acfa-922132f3143e",                        [{"alignmentgroup":"True","hovertemplate":"incomelevel=<=50K<br>hoursperweek=%{y}<extra></extra>","legendgroup":"<=50K","marker":{"color":"#636efa"},"name":"<=50K","notched":false,"offsetgroup":"<=50K","orientation":"v","showlegend":true,"type":"box","x0":" ","xaxis":"x","y":[40,13,40,40,40,40,16,30,50,45,35,40,50,20,40,40,40,40,80,40,52,44,40,40,15,40,40,25,40,43,40,50,40,35,38,40,40,43,40,60,40,40,48,40,40,40,58,40,40,32,40,40,20,40,40,22,40,30,40,40,48,35,50,40,40,40,25,50,40,40,50,40,40,40,40,40,40,25,40,50,50,56,41,40,60,40,35,28,40,60,40,35,50,36,60,35,20,40,40,30,40,30,24,24,40,38,40,40,35,46,40,2,60,50,40,40,40,40,42,40,16,20,40,40,50,25,40,40,12,65,40,45,40,40,50,28,40,40,45,24,40,40,40,40,40,35,40,60,12,40,40,40,40,50,55,40,40,40,20,35,40,50,20,40,40,38,42,40,40,38,40,20,50,40,34,40,30,40,20,40,30,45,40,40,60,12,40,40,45,24,98,35,40,40,40,40,15,45,42,40,45,40,40,45,40,56,45,40,16,60,40,80,25,40,40,45,33,40,15,40,40,40,40,24,40,50,45,40,10,45,40,55,45,40,40,40,40,48,40,60,30,40,40,20,40,42,25,25,40,30,40,35,40,24,45,55,40,45,15,40,15,10,40,40,10,40,40,30,50,40,45,40,40,40,25,40,16,40,50,40,35,40,40,40,40,64,40,40,25,50,24,40,40,40,40,19,40,40,30,18,40,35,60,40,72,40,40,40,60,40,40,40,40,28,40,40,35,40,40,40,40,40,50,60,40,40,50,40,20,60,40,40,40,60,24,40,6,30,40,35,45,20,20,40,20,45,40,35,40,60,25,20,36,40,40,35,40,40,40,42,40,40,8,40,40,40,42,45,45,20,50,40,9,50,40,46,40,40,50,30,40,45,40,40,40,40,50,45,8,40,36
# %%
g = sns.FacetGrid(df, col='incomelevel')
g.map(plt.hist, "sex")
g.set_xticklabels(rotation=90)

# %%
g = sns.FacetGrid(df, col='incomelevel')
g.map(plt.hist, "race")
g.set_xticklabels(rotation=90)

# %% [markdown]
# # Handling Categorical Variables

# %%
cat_cols = df[['workclass','education','maritalstatus','occupation','relationship','race','sex','nativecountry','incomelevel']]

for feature in cat_cols.columns[:]:
    print(feature,':',len(cat_cols[feature].unique()),'labels')
# Out:
# workclass : 7 labels
# education : 16 labels
# maritalstatus : 7 labels
# occupation : 14 labels
# relationship : 6 labels
# race : 5 labels
# sex : 2 labels
# nativecountry : 41 labels
# incomelevel : 2 labels

# %% [markdown]
# ### Income Level Variable

# %%
df['incomelevel'].unique()

dictionary={'<=50K':0,'>50K':1}
df['incomelevel'] = df.incomelevel.map(dictionary)

df.head()
# Out:
#    age         workclass  education  educationnum       maritalstatus  \
# 1   39         State-gov  Bachelors            13       Never-married
# 2   50  Self-emp-not-inc  Bachelors            13  Married-civ-spouse
# 3   38           Private    HS-grad             9            Divorced
# 4   53           Private       11th             7  Married-civ-spouse
# 5   28           Private  Bachelors            13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capitalgain  capitalloss  \
# 1       Adm-clerical  Not-in-family  White    Male         2174            0
# 2    Exec-managerial        Husband  White    Male            0            0
# 3  Handlers-cleaners  Not-in-family  White    Male            0            0
# 4  Handlers-cleaners        Husband  Black    Male            0            0
# 5     Prof-specialty           Wife  Black  Female            0            0
#
#    hoursperweek  nativecountry  incomelevel
# 1            40  United-States            0
# 2            13  United-States            0
# 3            40  United-States            0
# 4            40  United-States            0
# 5            40           Cuba            0

# %% [markdown]
# ### Workclass variable

# %%
df['workclass'].unique()

workclass_labels = df.groupby(['workclass'])['incomelevel'].mean().sort_values().index
print(workclass_labels)

workclass_labels2={k:i for i,k in enumerate(workclass_labels,0)}
print(workclass_labels2)

df['workclass'] = df['workclass'].map(workclass_labels2)
# Out:
# Index(['Without-pay', 'Private', 'State-gov', 'Self-emp-not-inc', 'Local-gov',
#        'Federal-gov', 'Self-emp-inc'],
#       dtype='object', name='workclass')
# {'Without-pay': 0, 'Private': 1, 'State-gov': 2, 'Self-emp-not-inc': 3, 'Local-gov': 4, 'Federal-gov': 5, 'Self-emp-inc': 6}

# %% [markdown]
# ### Education

# %%
df['education'].unique()

edu_labels = df.groupby(['education'])['incomelevel'].mean().sort_values().index
print(edu_labels)

edu_labels2={k:i for i,k in enumerate(edu_labels,0)}
print(edu_labels2)

df['education'] = df['education'].map(edu_labels2)
# Out:
# Index(['Preschool', '1st-4th', '5th-6th', '9th', '11th', '7th-8th', '10th',
#        '12th', 'HS-grad', 'Some-college', 'Assoc-acdm', 'Assoc-voc',
#        'Bachelors', 'Masters', 'Doctorate', 'Prof-school'],
#       dtype='object', name='education')
# {'Preschool': 0, '1st-4th': 1, '5th-6th': 2, '9th': 3, '11th': 4, '7th-8th': 5, '10th': 6, '12th': 7, 'HS-grad': 8, 'Some-college': 9, 'Assoc-acdm': 10, 'Assoc-voc': 11, 'Bachelors': 12, 'Masters': 13, 'Doctorate': 14, 'Prof-school': 15}

# %% [markdown]
# ### Marital Status

# %%
df['maritalstatus'].unique()

marital_labels = df.groupby(['maritalstatus'])['incomelevel'].mean().sort_values().index
print(marital_labels)

marital_labels2={k:i for i,k in enumerate(marital_labels,0)}
print(marital_labels2)

df['maritalstatus'] = df['maritalstatus'].map(marital_labels2)
# Out:
# Index(['Never-married', 'Separated', 'Married-spouse-absent', 'Widowed',
#        'Divorced', 'Married-civ-spouse', 'Married-AF-spouse'],
#       dtype='object', name='maritalstatus')
# {'Never-married': 0, 'Separated': 1, 'Married-spouse-absent': 2, 'Widowed': 3, 'Divorced': 4, 'Married-civ-spouse': 5, 'Married-AF-spouse': 6}

# %% [markdown]
# ### Occupation

# %%
df['occupation'].unique()

occ_labels = df.groupby(['occupation'])['incomelevel'].mean().sort_values().index
print(occ_labels)

occ_labels2={k:i for i,k in enumerate(occ_labels,0)}
print(occ_labels2)

df['occupation'] = df['occupation'].map(occ_labels2)
# Out:
# Index(['Priv-house-serv', 'Other-service', 'Handlers-cleaners', 'Armed-Forces',
#        'Farming-fishing', 'Machine-op-inspct', 'Adm-clerical',
#        'Transport-moving', 'Craft-repair', 'Sales', 'Tech-support',
#        'Protective-serv', 'Prof-specialty', 'Exec-managerial'],
#       dtype='object', name='occupation')
# {'Priv-house-serv': 0, 'Other-service': 1, 'Handlers-cleaners': 2, 'Armed-Forces': 3, 'Farming-fishing': 4, 'Machine-op-inspct': 5, 'Adm-clerical': 6, 'Transport-moving': 7, 'Craft-repair': 8, 'Sales': 9, 'Tech-support': 10, 'Protective-serv': 11, 'Prof-specialty': 12, 'Exec-managerial': 13}

# %% [markdown]
# ### Relationship

# %%
df['relationship'].unique()

rel_labels = df.groupby(['relationship'])['incomelevel'].mean().sort_values().index
print(rel_labels)

rel_labels2={k:i for i,k in enumerate(rel_labels,0)}
print(rel_labels2)

df['relationship'] = df['relationship'].map(rel_labels2)
# Out:
# Index(['Own-child', 'Other-relative', 'Unmarried', 'Not-in-family', 'Husband',
#        'Wife'],
#       dtype='object', name='relationship')
# {'Own-child': 0, 'Other-relative': 1, 'Unmarried': 2, 'Not-in-family': 3, 'Husband': 4, 'Wife': 5}

# %% [markdown]
# ### Race

# %%
df['race'].unique()

race_labels = df.groupby(['race'])['incomelevel'].mean().sort_values().index
print(race_labels)


race_labels2={k:i for i,k in enumerate(race_labels,0)}
print(race_labels2)

df['race'] = df['race'].map(race_labels2)
# Out:
# Index(['Other', 'Amer-Indian-Eskimo', 'Black', 'White', 'Asian-Pac-Islander'], dtype='object', name='race')
# {'Other': 0, 'Amer-Indian-Eskimo': 1, 'Black': 2, 'White': 3, 'Asian-Pac-Islander': 4}

# %% [markdown]
# ### Gender

# %%
df['sex'].unique()

sex_labels = df.groupby(['sex'])['incomelevel'].mean().sort_values().index
print(sex_labels)

sex_labels2={k:i for i,k in enumerate(sex_labels,0)}
sex_labels2

df['sex'] = df['sex'].map(sex_labels2)
# Out:
# Index(['Female', 'Male'], dtype='object', name='sex')

# %% [markdown]
# ### Native country

# %%
df['nativecountry'].unique()

nc_labels = df.groupby(['nativecountry'])['incomelevel'].mean().sort_values().index
print(nc_labels)


nc_labels2={k:i for i,k in enumerate(nc_labels,0)}
print(nc_labels2)

df['nativecountry'] = df['nativecountry'].map(nc_labels2)
# Out:
# Index(['Outlying-US(Guam-USVI-etc)', 'Holand-Netherlands',
#        'Dominican-Republic', 'Columbia', 'Guatemala', 'Mexico', 'Nicaragua',
#        'Peru', 'Vietnam', 'Honduras', 'El-Salvador', 'Haiti', 'Puerto-Rico',
#        'Trinadad&Tobago', 'Portugal', 'Laos', 'Jamaica', 'Ecuador', 'Thailand',
#        'Scotland', 'Poland', 'South', 'Ireland', 'Hungary', 'United-States',
#        'Cuba', 'Greece', 'China', 'Hong', 'Philippines', 'Canada', 'Germany',
#        'England', 'Italy', 'Yugoslavia', 'Cambodia', 'Japan', 'India', 'Iran',
#        'France', 'Taiwan'],
#       dtype='object', name='nativecountry')
# {'Outlying-US(Guam-USVI-etc)': 0, 'Holand-Netherlands': 1, 'Dominican-Republic': 2, 'Columbia': 3, 'Guatemala': 4, 'Mexico': 5, 'Nicaragua': 6, 'Peru': 7, 'Vietnam': 8, 'Honduras': 9, 'El-Salvador': 10, 'Haiti': 11, 'Puerto-Rico': 12, 'Trinadad&Tobago': 13, 'Portugal': 14, 'Laos': 15, 'Jamaica': 16, 'Ecuador': 17, 'Thailand': 18, 'Scotland': 19, 'Poland': 20, 'South': 21, 'Ireland': 22, 'Hungary': 23, 'United-States': 24, 'Cuba': 25, 'Greece': 26, 'China': 27, 'Hong': 28, 'Philippines': 29, 'Canada': 30, 'Germany': 31, 'England': 32, 'Italy': 33, 'Yugoslavia': 34, 'Cambodia': 35, 'Japan': 36, 'India': 37, 'Iran': 38, 'France': 39, 'Taiwan': 40}

# %%
df.head(50)
# Out:
#              income student credit_rating buys_computer
# age
# youth          high      no          fair            no
# youth          high      no     excellent            no
# middle_aged    high      no          fair           yes
# senior       medium      no          fair           yes
# senior          low     yes          fair           yes
# senior          low     yes     excellent            no
# middle_aged     low     yes     excellent           yes
# youth        medium      no          fair            no
# youth           low     yes          fair           yes
# senior       medium     yes          fair           yes
# youth        medium     yes     excellent           yes
# middle_aged  medium      no     excellent           yes
# middle_aged    high     yes          fair           yes
# senior       medium      no     excellent            no

# %% [markdown]
# # Building Model

# %%
from sklearn.model_selection import train_test_split
import sklearn as sk

# %%
X = df.iloc[:,:-1]

# %%
y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier().fit(X_train, y_train)
print('Accuracy of Decision Tree classifier on training set: {:.2f}'
     .format(clf.score(X_train, y_train)))
print('Accuracy of Decision Tree classifier on test set: {:.2f}'
     .format(clf.score(X_test, y_test)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [24], line 2
#       1 from sklearn.tree import DecisionTreeClassifier
# ----> 2 clf = DecisionTreeClassifier().fit(X_train, y_train)
#       3 print('Accuracy of Decision Tree classifier on training set: {:.2f}'
#       4      .format(clf.score(X_train, y_train)))
#       5 print('Accuracy of Decision Tree classifier on test set: {:.2f}'
#       6      .format(clf.score(X_test, y_test)))
#
# File c:\Python310\lib\site-packages\sklearn\tree\_classes.py:969, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     939 def fit(self, X, y, sample_weight=None, check_input=True):
#     940     """Build a decision tree classifier from the training set (X, y).
#     941
#     942     Parameters
#    (...)
#     966         Fitted estimator.
#     967     """
# --> 969     super().fit(
#     970         X,
#     971         y,
#     972         sample_weight=sample_weight,
#     973         check_input=check_input,
#     974     )
#     975     return self
#
# File c:\Python310\lib\site-packages\sklearn\tree\_classes.py:172, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     170 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     171 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 172 X, y = self._validate_data(
#     173     X, y, validate_separately=(check_X_params, check_y_params)
#     174 )
#     175 if issparse(X):
#     176     X.sort_indices()
#
# File c:\Python310\lib\site-packages\sklearn\base.py:591, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     589 if "estimator" not in check_X_params:
#     590     check_X_params = {**default_check_params, **check_X_params}
# --> 591 X = check_array(X, input_name="X", **check_X_params)
#     592 if "estimator" not in check_y_params:
#     593     check_y_params = {**default_check_params, **check_y_params}
#
# File c:\Python310\lib\site-packages\sklearn\utils\validation.py:856, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854         array = array.astype(dtype, casting="unsafe", copy=False)
#     855     else:
# --> 856         array = np.asarray(array, order=order, dtype=dtype)
#     857 except ComplexWarning as complex_warning:
#     858     raise ValueError(
#     859         "Complex data not supported\n{}\n".format(array)
#     860     ) from complex_warning
#
# File c:\Python310\lib\site-packages\pandas\core\generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'low'

# %%
pred = clf.predict(X_test)

# %%
#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix  
cm= confusion_matrix(y_test, pred)  
cm
# Out:
# array([[5965,  802],
#        [ 867, 1415]], dtype=int64)

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test, pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88      6767
#            1       0.64      0.62      0.63      2282
#
#     accuracy                           0.82      9049
#    macro avg       0.76      0.75      0.75      9049
# weighted avg       0.81      0.82      0.81      9049

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.8155597303569455

# %% [markdown]
# # Predicting actual test values

# %% [markdown]
# #### Performing all the cleaning anf feature engineerig process in test dataset

# %%
df_test = df_test.iloc[1:,:]

# %%
df_test.replace('NaN', np.nan, inplace=True)
df_test.fillna('', inplace=True)

# %%
df_test.head()
# Out:
#   age  workclass     education  educationnum       maritalstatus  \
# 2  25    Private          11th           7.0       Never-married
# 3  38    Private       HS-grad           9.0  Married-civ-spouse
# 4  28  Local-gov    Assoc-acdm          12.0  Married-civ-spouse
# 5  44    Private  Some-college          10.0  Married-civ-spouse
# 7  34    Private          10th           6.0       Never-married
#
#           occupation   relationship   race   sex  capitalgain  capitalloss  \
# 2  Machine-op-inspct      Own-child  Black  Male          0.0          0.0
# 3    Farming-fishing        Husband  White  Male          0.0          0.0
# 4    Protective-serv        Husband  White  Male          0.0          0.0
# 5  Machine-op-inspct        Husband  Black  Male       7688.0          0.0
# 7      Other-service  Not-in-family  White  Male          0.0          0.0
#
#    hoursperweek  nativecountry incomelevel
# 2          40.0  United-States      <=50K.
# 3          50.0  United-States      <=50K.
# 4          40.0  United-States       >50K.
# 5          40.0  United-States       >50K.
# 7          30.0  United-States      <=50K.

# %%
df_test.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationnum     0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# nativecountry    0
# incomelevel      0
# dtype: int64

# %% [markdown]
# ### Categorical Values

# %%
df_test.head()
# Out:
#   age  workclass     education  educationnum       maritalstatus  \
# 2  25    Private          11th           7.0       Never-married
# 3  38    Private       HS-grad           9.0  Married-civ-spouse
# 4  28  Local-gov    Assoc-acdm          12.0  Married-civ-spouse
# 5  44    Private  Some-college          10.0  Married-civ-spouse
# 7  34    Private          10th           6.0       Never-married
#
#           occupation   relationship   race   sex  capitalgain  capitalloss  \
# 2  Machine-op-inspct      Own-child  Black  Male          0.0          0.0
# 3    Farming-fishing        Husband  White  Male          0.0          0.0
# 4    Protective-serv        Husband  White  Male          0.0          0.0
# 5  Machine-op-inspct        Husband  Black  Male       7688.0          0.0
# 7      Other-service  Not-in-family  White  Male          0.0          0.0
#
#    hoursperweek  nativecountry incomelevel
# 2          40.0  United-States      <=50K.
# 3          50.0  United-States      <=50K.
# 4          40.0  United-States       >50K.
# 5          40.0  United-States       >50K.
# 7          30.0  United-States      <=50K.

# %%
df_test['incomelevel'].unique()

dictionary={'<=50K.':0,'>50K.':1}
df_test['incomelevel'] = df_test.incomelevel.map(dictionary)

# %%
df_test['workclass'].unique()

workclass_labels = df_test.groupby(['workclass'])['incomelevel'].mean().sort_values().index
print(workclass_labels)

enumerate(workclass_labels,0)

workclass_labels2={k:i for i,k in enumerate(workclass_labels,0)}
workclass_labels2

df_test['workclass'] = df_test['workclass'].map(workclass_labels2)
# Out:
# Index(['Private', 'State-gov', 'Self-emp-not-inc', 'Without-pay', 'Local-gov',
#        'Federal-gov', 'Self-emp-inc'],
#       dtype='object', name='workclass')

# %%
df_test['education'].unique()

edu_labels = df_test.groupby(['education'])['incomelevel'].mean().sort_values().index
print(edu_labels)

enumerate(edu_labels,0)

edu_labels2={k:i for i,k in enumerate(edu_labels,0)}
edu_labels2

df_test['education'] = df_test['education'].map(edu_labels2)

# %%
df_test['maritalstatus'].unique()

marital_labels = df_test.groupby(['maritalstatus'])['incomelevel'].mean().sort_values().index
print(marital_labels)

enumerate(marital_labels,0)

marital_labels2={k:i for i,k in enumerate(marital_labels,0)}
marital_labels2

df_test['maritalstatus'] = df_test['maritalstatus'].map(marital_labels2)

# %%
df_test['occupation'].unique()

occ_labels = df_test.groupby(['occupation'])['incomelevel'].mean().sort_values().index
print(occ_labels)

enumerate(occ_labels,0)

occ_labels2={k:i for i,k in enumerate(occ_labels,0)}
occ_labels2

df_test['occupation'] = df_test['occupation'].map(occ_labels2)

# %%
df_test['relationship'].unique()

rel_labels = df_test.groupby(['relationship'])['incomelevel'].mean().sort_values().index
print(rel_labels)

enumerate(rel_labels,0)

rel_labels2={k:i for i,k in enumerate(rel_labels,0)}
rel_labels2

df_test['relationship'] = df_test['relationship'].map(rel_labels2)

# %%
df_test['race'].unique()

race_labels = df_test.groupby(['race'])['incomelevel'].mean().sort_values().index
print(race_labels)

enumerate(race_labels,0)

race_labels2={k:i for i,k in enumerate(race_labels,0)}
race_labels2

df_test['race'] = df_test['race'].map(race_labels2)

# %%
df_test['sex'].unique()

sex_labels = df_test.groupby(['sex'])['incomelevel'].mean().sort_values().index
print(sex_labels)

enumerate(sex_labels,0)

sex_labels2={k:i for i,k in enumerate(sex_labels,0)}
sex_labels2

df_test['sex'] = df_test['sex'].map(sex_labels2)

# %%
df_test['nativecountry'].unique()

nc_labels = df_test.groupby(['nativecountry'])['incomelevel'].mean().sort_values().index
print(nc_labels)

enumerate(nc_labels,0)

nc_labels2={k:i for i,k in enumerate(nc_labels,0)}
nc_labels2

df_test['nativecountry'] = df_test['nativecountry'].map(nc_labels2)

# %%
df_test.head()

# %%
X = df_test.iloc[:, :-1].values
y = df_test.iloc[:,-1]

# %%
y

# %% [markdown]
# ### Creating a Pickle file

# %%
import pickle
file = open('incomepredictions.pkl','wb')
#dump information to that file
pickle.dump(clf, file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c3f9387bf9ea> in <module>
#       2 file = open('incomepredictions.pkl','wb')
#       3 #dump information to that file
# ----> 4 pickle.dump(clf, file)
#
# NameError: name 'clf' is not defined

# %%
# pip install flask
# pip install os
# pip install jsonify
# pip install requests
